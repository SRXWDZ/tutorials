# %%
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))


obj = ExpensiveObject()
r = weakref.ref(obj)

print('obj:', obj)
print('ref:', r)
print('r():', r())

print('deleting obj')
del obj
print('r():', r())
# Out:
# obj: <__main__.ExpensiveObject object at 0x000001E9062C8F70>
# ref: <weakref at 0x000001E9062D75E0; to 'ExpensiveObject' at 0x000001E9062C8F70>
# r(): <__main__.ExpensiveObject object at 0x000001E9062C8F70>
# deleting obj
# (Deleting <__main__.ExpensiveObject object at 0x000001E9062C8F70>)
# r(): None

# %%
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))


def callback(reference):
    """Invoked when referenced object is deleted"""
    print('callback({!r})'.format(reference))


obj = ExpensiveObject()
r = weakref.ref(obj, callback)

print('obj:', obj)
print('ref:', r)
print('r():', r())

print('deleting obj')
del obj
print('r():', r())
# Out:
# obj: <__main__.ExpensiveObject object at 0x000001E9062DC1F0>
# ref: <weakref at 0x000001E9062DE0E0; to 'ExpensiveObject' at 0x000001E9062DC1F0>
# r(): <__main__.ExpensiveObject object at 0x000001E9062DC1F0>
# deleting obj
# (Deleting <__main__.ExpensiveObject object at 0x000001E9062DC1F0>)
# callback(<weakref at 0x000001E9062DE0E0; dead>)
# r(): None

# %%
import os
os._exit(00)

# %%
import sys
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))


def on_finalize(*args):
    print('on_finalize({!r})'.format(args))


obj = ExpensiveObject()
f = weakref.finalize(obj, on_finalize, 'extra argument')
f.atexit = True
# Out:
# (Deleting <__main__.ExpensiveObject object at 0x00000252896ABA00>)
# on_finalize(('extra argument',))

# %%
import os
os._exit(00)

# %%
import sys
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))


def on_finalize(*args):
    print('on_finalize({!r})'.format(args))

obj = ExpensiveObject()
f = weakref.finalize(obj, on_finalize, 'extra argument')
f.atexit = False

# %%
import os
os._exit(00)

# %%
import gc
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))


def on_finalize(*args):
    print('on_finalize({!r})'.format(args))


obj = ExpensiveObject()
obj_id = id(obj)
f = weakref.finalize(obj, on_finalize, obj)
f.atexit = False

del obj

for o in gc.get_objects():
    if id(o) == obj_id:
        print('found uncollected object in gc')
# Out:
# found uncollected object in gc

# %%
import os
os._exit(00)

# %%
import gc
import weakref


class ExpensiveObject:

    def __del__(self):
        print('(Deleting {})'.format(self))

    def do_finalize(self):
        print('do_finalize')


obj = ExpensiveObject()
obj_id = id(obj)

f = weakref.finalize(obj, obj.do_finalize)
f.atexit = False

del obj

for o in gc.get_objects():
    if id(o) == obj_id:
        print('found uncollected object in gc')
# Out:
# found uncollected object in gc

# %%
import weakref


class ExpensiveObject:

    def __init__(self, name):
        self.name = name

    def __del__(self):
        print('(Deleting {})'.format(self))


obj = ExpensiveObject('My Object')
r = weakref.ref(obj)
p = weakref.proxy(obj)

print('via obj:', obj.name)
print('via ref:', r().name)
print('via proxy:', p.name)
del obj
print('via proxy:', p.name)
# Out:
# via obj: My Object
# via ref: My Object
# via proxy: My Object
# (Deleting <__main__.ExpensiveObject object at 0x000001B42DCFBD00>)
# ---------------------------------------------------------------------------
# ReferenceError                            Traceback (most recent call last)
# <ipython-input-3-d8a702148345> in <module>
#      19 print('via proxy:', p.name)
#      20 del obj
# ---> 21 print('via proxy:', p.name)
#
# ReferenceError: weakly-referenced object no longer exists

# %%
import os
os._exit(00)

# %%
import gc
from pprint import pprint
import weakref

gc.set_debug(gc.DEBUG_UNCOLLECTABLE)


class ExpensiveObject:

    def __init__(self, name):
        self.name = name

    def __repr__(self):
        return 'ExpensiveObject({})'.format(self.name)

    def __del__(self):
        print('    (Deleting {})'.format(self))


def demo(cache_factory):
    # hold objects so any weak references
    # are not removed immediately
    all_refs = {}
    # create the cache using the factory
    print('CACHE TYPE:', cache_factory)
    cache = cache_factory()
    for name in ['one', 'two', 'three']:
        o = ExpensiveObject(name)
        cache[name] = o
        all_refs[name] = o
        del o  # decref

    print('  all_refs =', end=' ')
    pprint(all_refs)
    print('\n  Before, cache contains:', list(cache.keys()))
    for name, value in cache.items():
        print('    {} = {}'.format(name, value))
        del value  # decref

    # remove all references to the objects except the cache
    print('\n  Cleanup:')
    del all_refs
    gc.collect()

    print('\n  After, cache contains:', list(cache.keys()))
    for name, value in cache.items():
        print('    {} = {}'.format(name, value))
    print('  demo returning')
    return


demo(dict)
print()

demo(weakref.WeakValueDictionary)
# Out:
# CACHE TYPE: <class 'dict'>
#   all_refs = {'one': ExpensiveObject(one),
#  'three': ExpensiveObject(three),
#  'two': ExpensiveObject(two)}
#
#   Before, cache contains: ['one', 'two', 'three']
#     one = ExpensiveObject(one)
#     two = ExpensiveObject(two)
#     three = ExpensiveObject(three)
#
#   Cleanup:
#
#   After, cache contains: ['one', 'two', 'three']
#     one = ExpensiveObject(one)
#     two = ExpensiveObject(two)
#     three = ExpensiveObject(three)
#   demo returning
#     (Deleting ExpensiveObject(one))
#     (Deleting ExpensiveObject(two))
#     (Deleting ExpensiveObject(three))
#
# CACHE TYPE: <class 'weakref.WeakValueDictionary'>
#   all_refs = {'one': ExpensiveObject(one),
#  'three': ExpensiveObject(three),
#  'two': ExpensiveObject(two)}
#
#   Before, cache contains: ['one', 'two', 'three']
#     one = ExpensiveObject(one)
#     two = ExpensiveObject(two)
#     three = ExpensiveObject(three)
#
#   Cleanup:
#     (Deleting ExpensiveObject(one))
#     (Deleting ExpensiveObject(two))
#     (Deleting ExpensiveObject(three))
#
#   After, cache contains: []
#   demo returning

# %%
import gc
from pprint import pprint
import weakref

class Graph:
    def __init__(self, name):
        self.name = name
        self.other = None
    def set_next(self, other):
        print(f"{self.name}.set_next({self.other}, {type(other)})")
        self.other = other
    def all_nodes(self):
        "Generate the nodes in the graph sequence."
        yield self
        n = self.other
        while n and n.name != self.name:
            yield n
            n = n.other
        if n is self:
            yield n
        return
    def __str__(self):
        return "->".join([n.name for n in self.all_nodes()])
    def __repr__(self):
        return f"{self.__class__.__name__}({self.name})"
    def __del__(self):
        print (f'(Deleting {self.name})')
        self.set_next(None)
        
        
class WeakGraph(Graph):
    def set_next(self, other):
        if other is not None:
            if self in other.all_nodes():
                other = weakref.proxy(other)
        super(WeakGraph, self).set_next(other)
        return
    
def collect_and_show_garbage():
    "show what garbage is present."
    print("Collecting...")
    n = gc.collect()
    print("Unreachable objects:", n)
    print("Garbage:")
    pprint(gc.garbage)

def demo(graph_factory):
    print("Set up graph:")
    one = graph_factory("one")
    two = graph_factory("two")
    three = graph_factory("three")
    one.set_next(two)
    two.set_next(three)
    three.set_next(one)
    
    print("\nGraphs:")
    print(str(one))
    print(str(two))
    print(str(three))
    collect_and_show_garbage()     
    
    print('\n')
    three = None
    two = None
    print("After 2 references removed:")
    print(str(one))
    collect_and_show_garbage()     
    
    print("\n")
    print("Removing last reference:")
    one = None
    collect_and_show_garbage()
# Out:
# gc: collectable <tuple 0x00000251DE317460>
# gc: collectable <ValueError 0x00000251DE3C5360>
# gc: collectable <traceback 0x00000251DE265A80>
# gc: collectable <frame 0x00000251DE3F2840>
# gc: collectable <traceback 0x00000251DE2CAB80>
# gc: collectable <tuple 0x00000251DE37D790>
# gc: collectable <ValueError 0x00000251DE367400>
# gc: collectable <traceback 0x00000251DE2CA100>
# gc: collectable <frame 0x00000251DCA0D530>
# gc: collectable <traceback 0x00000251DE2CAFC0>
# gc: collectable <frame 0x00000251DE3F2C40>
# gc: collectable <traceback 0x00000251DE2CA7C0>
# gc: collectable <frame 0x00000251DE3F6040>
# gc: collectable <frame 0x00000251DDBBB470>
# gc: collectable <frame 0x00000251DDBD2350>

# %%
gc.set_debug(gc.DEBUG_LEAK)

# %%
print ('Setting up the cycle\n')
demo(Graph)
print('\nBreaking the cycle and cleaning up garbage\n')
gc.garbage[0].set_next(None)
while gc.garbage:
    del gc.garbage[0]
print('\n')
collect_and_show_garbage()
# Out:
# Setting up the cycle
#
# Set up graph:
# one.set_next(None, <class '__main__.Graph'>)
# two.set_next(None, <class '__main__.Graph'>)
# three.set_next(None, <class '__main__.Graph'>)
#
# Graphs:
# one->two->three->one
# two->three->one->two
# three->one->two->three
# Collecting...
# Unreachable objects: 58
# Garbage:
# [('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2FF640>,
#  <frame at 0x00000251DE27CA60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE315980>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE3153C0>,
#  <frame at 0x00000251DCA0D740, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE315700>,
#  <frame at 0x00000251DE275C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE315900>,
#  <frame at 0x00000251DE24B780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE279C80, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBBC9B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD8DEF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 3, 490484, tzinfo=datetime.timezone.utc),
#              'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE310480>,
#  <frame at 0x00000251DDBBC790, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE30B340>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30B540>,
#  <frame at 0x00000251DCA0D110, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE30B640>,
#  <frame at 0x00000251DE348840, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE305580>,
#  <frame at 0x00000251DE347780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE33B200, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2DF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#  {'_action_max_length': 0,
#   '_current_indent': 0,
#   '_current_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_indent_increment': 2,
#   '_level': 0,
#   '_long_break_matcher': re.compile('\\n\\n\\n+'),
#   '_max_help_position': 24,
#   '_prog': 'named_script_magic',
#   '_root_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_whitespace_matcher': re.compile('\\s+', re.ASCII),
#   '_width': 118},
#  <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#  {'formatter': <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#   'heading': None,
#   'items': [],
#   'parent': None},
#  [],
#  <frame at 0x00000251DDD8E7B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 2, 657550, tzinfo=datetime.timezone.utc),
#              'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <frame at 0x00000251DDD90F10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 4, 358937, tzinfo=datetime.timezone.utc),
#              'msg_id': 'd417b7a01cf341c5830432383ad20933',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'd417b7a01cf341c5830432383ad20933',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2E3700>,
#  <frame at 0x00000251DE381DC0, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CCBC0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CCE80>,
#  <frame at 0x00000251DCA0DF80, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CC800>,
#  <frame at 0x00000251DE345C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CC900>,
#  <frame at 0x00000251DDBCFAF0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE353740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD18B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE265A80>,
#  <frame at 0x00000251DE3F2840, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CAB80>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CA100>,
#  <frame at 0x00000251DCA0D530, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CAFC0>,
#  <frame at 0x00000251DE3F2C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CA7C0>,
#  <frame at 0x00000251DE3F6040, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBBB470, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2350, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <class '__main__.WeakGraph'>,
#  {'__doc__': None,
#   '__module__': '__main__',
#   'set_next': <function WeakGraph.set_next at 0x00000251DE32DDC0>},
#  (<class '__main__.WeakGraph'>, <class '__main__.Graph'>, <class 'object'>),
#  (<class '__main__.Graph'>,),
#  <function WeakGraph.set_next at 0x00000251DE32DDC0>,
#  (<cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,),
#  <cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,
#  <class '__main__.Graph'>,
#  {'__del__': <function Graph.__del__ at 0x00000251DE32DD30>,
#   '__dict__': <attribute '__dict__' of 'Graph' objects>,
#   '__doc__': None,
#   '__init__': <function Graph.__init__ at 0x00000251DE32DA60>,
#   '__module__': '__main__',
#   '__repr__': <function Graph.__repr__ at 0x00000251DE32DCA0>,
#   '__str__': <function Graph.__str__ at 0x00000251DE32DC10>,
#   '__weakref__': <attribute '__weakref__' of 'Graph' objects>,
#   'all_nodes': <function Graph.all_nodes at 0x00000251DE32DB80>,
#   'set_next': <function Graph.set_next at 0x00000251DE32DAF0>},
#  (<class '__main__.Graph'>, <class 'object'>),
#  <function Graph.__init__ at 0x00000251DE32DA60>,
#  <function Graph.set_next at 0x00000251DE32DAF0>,
#  <function Graph.all_nodes at 0x00000251DE32DB80>,
#  <function Graph.__str__ at 0x00000251DE32DC10>,
#  <function Graph.__repr__ at 0x00000251DE32DCA0>,
#  <function Graph.__del__ at 0x00000251DE32DD30>,
#  <attribute '__dict__' of 'Graph' objects>,
#  <attribute '__weakref__' of 'Graph' objects>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE31EA40>,
#  <frame at 0x00000251DE328A40, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DD887C00>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF0C0>,
#  <frame at 0x00000251DCA0E7C0, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF700>,
#  <frame at 0x00000251DE350040, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE256F40>,
#  <frame at 0x00000251DDD90880, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE334740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2570, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDE9B1D0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 8, 903426, tzinfo=datetime.timezone.utc),
#              'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30E800>,
#  <frame at 0x00000251DDE9C190, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE245240>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE245580>,
#  <frame at 0x00000251DCA0F000, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE245F80>,
#  <frame at 0x00000251DE350440, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2456C0>,
#  <frame at 0x00000251DDBD09D0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBCF490, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD1CF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD901F0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 7, 457825, tzinfo=datetime.timezone.utc),
#              'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  []]
#
#
# After 2 references removed:
# one->two->three->one
# Collecting...
# Unreachable objects: 0
# Garbage:
# [('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2FF640>,
#  <frame at 0x00000251DE27CA60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE315980>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE3153C0>,
#  <frame at 0x00000251DCA0D740, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE315700>,
#  <frame at 0x00000251DE275C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE315900>,
#  <frame at 0x00000251DE24B780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE279C80, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBBC9B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD8DEF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 3, 490484, tzinfo=datetime.timezone.utc),
#              'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE310480>,
#  <frame at 0x00000251DDBBC790, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE30B340>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30B540>,
#  <frame at 0x00000251DCA0D110, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE30B640>,
#  <frame at 0x00000251DE348840, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE305580>,
#  <frame at 0x00000251DE347780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE33B200, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2DF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#  {'_action_max_length': 0,
#   '_current_indent': 0,
#   '_current_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_indent_increment': 2,
#   '_level': 0,
#   '_long_break_matcher': re.compile('\\n\\n\\n+'),
#   '_max_help_position': 24,
#   '_prog': 'named_script_magic',
#   '_root_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_whitespace_matcher': re.compile('\\s+', re.ASCII),
#   '_width': 118},
#  <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#  {'formatter': <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#   'heading': None,
#   'items': [],
#   'parent': None},
#  [],
#  <frame at 0x00000251DDD8E7B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 2, 657550, tzinfo=datetime.timezone.utc),
#              'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <frame at 0x00000251DDD90F10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 4, 358937, tzinfo=datetime.timezone.utc),
#              'msg_id': 'd417b7a01cf341c5830432383ad20933',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'd417b7a01cf341c5830432383ad20933',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2E3700>,
#  <frame at 0x00000251DE381DC0, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CCBC0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CCE80>,
#  <frame at 0x00000251DCA0DF80, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CC800>,
#  <frame at 0x00000251DE345C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CC900>,
#  <frame at 0x00000251DDBCFAF0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE353740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD18B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE265A80>,
#  <frame at 0x00000251DE3F2840, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CAB80>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CA100>,
#  <frame at 0x00000251DCA0D530, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CAFC0>,
#  <frame at 0x00000251DE3F2C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CA7C0>,
#  <frame at 0x00000251DE3F6040, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBBB470, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2350, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <class '__main__.WeakGraph'>,
#  {'__doc__': None,
#   '__module__': '__main__',
#   'set_next': <function WeakGraph.set_next at 0x00000251DE32DDC0>},
#  (<class '__main__.WeakGraph'>, <class '__main__.Graph'>, <class 'object'>),
#  (<class '__main__.Graph'>,),
#  <function WeakGraph.set_next at 0x00000251DE32DDC0>,
#  (<cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,),
#  <cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,
#  <class '__main__.Graph'>,
#  {'__del__': <function Graph.__del__ at 0x00000251DE32DD30>,
#   '__dict__': <attribute '__dict__' of 'Graph' objects>,
#   '__doc__': None,
#   '__init__': <function Graph.__init__ at 0x00000251DE32DA60>,
#   '__module__': '__main__',
#   '__repr__': <function Graph.__repr__ at 0x00000251DE32DCA0>,
#   '__str__': <function Graph.__str__ at 0x00000251DE32DC10>,
#   '__weakref__': <attribute '__weakref__' of 'Graph' objects>,
#   'all_nodes': <function Graph.all_nodes at 0x00000251DE32DB80>,
#   'set_next': <function Graph.set_next at 0x00000251DE32DAF0>},
#  (<class '__main__.Graph'>, <class 'object'>),
#  <function Graph.__init__ at 0x00000251DE32DA60>,
#  <function Graph.set_next at 0x00000251DE32DAF0>,
#  <function Graph.all_nodes at 0x00000251DE32DB80>,
#  <function Graph.__str__ at 0x00000251DE32DC10>,
#  <function Graph.__repr__ at 0x00000251DE32DCA0>,
#  <function Graph.__del__ at 0x00000251DE32DD30>,
#  <attribute '__dict__' of 'Graph' objects>,
#  <attribute '__weakref__' of 'Graph' objects>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE31EA40>,
#  <frame at 0x00000251DE328A40, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DD887C00>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF0C0>,
#  <frame at 0x00000251DCA0E7C0, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF700>,
#  <frame at 0x00000251DE350040, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE256F40>,
#  <frame at 0x00000251DDD90880, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE334740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2570, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDE9B1D0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 8, 903426, tzinfo=datetime.timezone.utc),
#              'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30E800>,
#  <frame at 0x00000251DDE9C190, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE245240>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
# ...
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'd417b7a01cf341c5830432383ad20933',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2E3700>,
#  <frame at 0x00000251DE381DC0, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CCBC0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CCE80>,
#  <frame at 0x00000251DCA0DF80, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CC800>,
#  <frame at 0x00000251DE345C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CC900>,
#  <frame at 0x00000251DDBCFAF0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE353740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD18B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE265A80>,
#  <frame at 0x00000251DE3F2840, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CAB80>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CA100>,
#  <frame at 0x00000251DCA0D530, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CAFC0>,
#  <frame at 0x00000251DE3F2C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CA7C0>,
#  <frame at 0x00000251DE3F6040, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBBB470, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2350, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <class '__main__.WeakGraph'>,
#  {'__doc__': None,
#   '__module__': '__main__',
#   'set_next': <function WeakGraph.set_next at 0x00000251DE32DDC0>},
#  (<class '__main__.WeakGraph'>, <class '__main__.Graph'>, <class 'object'>),
#  (<class '__main__.Graph'>,),
#  <function WeakGraph.set_next at 0x00000251DE32DDC0>,
#  (<cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,),
#  <cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,
#  <class '__main__.Graph'>,
#  {'__del__': <function Graph.__del__ at 0x00000251DE32DD30>,
#   '__dict__': <attribute '__dict__' of 'Graph' objects>,
#   '__doc__': None,
#   '__init__': <function Graph.__init__ at 0x00000251DE32DA60>,
#   '__module__': '__main__',
#   '__repr__': <function Graph.__repr__ at 0x00000251DE32DCA0>,
#   '__str__': <function Graph.__str__ at 0x00000251DE32DC10>,
#   '__weakref__': <attribute '__weakref__' of 'Graph' objects>,
#   'all_nodes': <function Graph.all_nodes at 0x00000251DE32DB80>,
#   'set_next': <function Graph.set_next at 0x00000251DE32DAF0>},
#  (<class '__main__.Graph'>, <class 'object'>),
#  <function Graph.__init__ at 0x00000251DE32DA60>,
#  <function Graph.set_next at 0x00000251DE32DAF0>,
#  <function Graph.all_nodes at 0x00000251DE32DB80>,
#  <function Graph.__str__ at 0x00000251DE32DC10>,
#  <function Graph.__repr__ at 0x00000251DE32DCA0>,
#  <function Graph.__del__ at 0x00000251DE32DD30>,
#  <attribute '__dict__' of 'Graph' objects>,
#  <attribute '__weakref__' of 'Graph' objects>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE31EA40>,
#  <frame at 0x00000251DE328A40, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DD887C00>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF0C0>,
#  <frame at 0x00000251DCA0E7C0, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF700>,
#  <frame at 0x00000251DE350040, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE256F40>,
#  <frame at 0x00000251DDD90880, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE334740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2570, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDE9B1D0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 8, 903426, tzinfo=datetime.timezone.utc),
#              'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30E800>,
#  <frame at 0x00000251DDE9C190, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE245240>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE245580>,
#  <frame at 0x00000251DCA0F000, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE245F80>,
#  <frame at 0x00000251DE350440, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2456C0>,
#  <frame at 0x00000251DDBD09D0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBCF490, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD1CF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD901F0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 7, 457825, tzinfo=datetime.timezone.utc),
#              'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  []]
#
# Breaking the cycle and cleaning up garbage
# gc: collectable <dict 0x00000251DE407880>
# gc: collectable <Graph 0x00000251DE2FEE20>
# gc: collectable <dict 0x00000251DE407940>
# gc: collectable <Graph 0x00000251DE2FEBB0>
# gc: collectable <dict 0x00000251DE4079C0>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-5ce870f7c563> in <module>
#       2 demo(Graph)
#       3 print('\nBreaking the cycle and cleaning up garbage\n')
# ----> 4 gc.garbage[0].set_next(None)
#       5 while gc.garbage:
#       6     del gc.garbage[0]
#
# AttributeError: 'tuple' object has no attribute 'set_next'

# %%
demo(WeakGraph)
# Out:
# Set up graph:
# one.set_next(None, <class '__main__.WeakGraph'>)
# two.set_next(None, <class '__main__.WeakGraph'>)
# three.set_next(None, <class 'weakproxy'>)
#
# Graphs:
# one->two->three
# two->three->one->two
# three->one->two->three
# Collecting...
# Unreachable objects: 28
# Garbage:
# [('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2FF640>,
#  <frame at 0x00000251DE27CA60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE315980>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE3153C0>,
#  <frame at 0x00000251DCA0D740, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE315700>,
#  <frame at 0x00000251DE275C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE315900>,
#  <frame at 0x00000251DE24B780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE279C80, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBBC9B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD8DEF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 3, 490484, tzinfo=datetime.timezone.utc),
#              'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE310480>,
#  <frame at 0x00000251DDBBC790, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE30B340>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30B540>,
#  <frame at 0x00000251DCA0D110, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE30B640>,
#  <frame at 0x00000251DE348840, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE305580>,
#  <frame at 0x00000251DE347780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE33B200, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2DF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#  {'_action_max_length': 0,
#   '_current_indent': 0,
#   '_current_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_indent_increment': 2,
#   '_level': 0,
#   '_long_break_matcher': re.compile('\\n\\n\\n+'),
#   '_max_help_position': 24,
#   '_prog': 'named_script_magic',
#   '_root_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_whitespace_matcher': re.compile('\\s+', re.ASCII),
#   '_width': 118},
#  <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#  {'formatter': <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#   'heading': None,
#   'items': [],
#   'parent': None},
#  [],
#  <frame at 0x00000251DDD8E7B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 2, 657550, tzinfo=datetime.timezone.utc),
#              'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <frame at 0x00000251DDD90F10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 4, 358937, tzinfo=datetime.timezone.utc),
#              'msg_id': 'd417b7a01cf341c5830432383ad20933',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'd417b7a01cf341c5830432383ad20933',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2E3700>,
#  <frame at 0x00000251DE381DC0, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CCBC0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CCE80>,
#  <frame at 0x00000251DCA0DF80, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CC800>,
#  <frame at 0x00000251DE345C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CC900>,
#  <frame at 0x00000251DDBCFAF0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE353740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD18B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE265A80>,
#  <frame at 0x00000251DE3F2840, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CAB80>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CA100>,
#  <frame at 0x00000251DCA0D530, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CAFC0>,
#  <frame at 0x00000251DE3F2C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CA7C0>,
#  <frame at 0x00000251DE3F6040, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBBB470, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2350, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <class '__main__.WeakGraph'>,
#  {'__doc__': None,
#   '__module__': '__main__',
#   'set_next': <function WeakGraph.set_next at 0x00000251DE32DDC0>},
#  (<class '__main__.WeakGraph'>, <class '__main__.Graph'>, <class 'object'>),
#  (<class '__main__.Graph'>,),
#  <function WeakGraph.set_next at 0x00000251DE32DDC0>,
#  (<cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,),
#  <cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,
#  <class '__main__.Graph'>,
#  {'__del__': <function Graph.__del__ at 0x00000251DE32DD30>,
#   '__dict__': <attribute '__dict__' of 'Graph' objects>,
#   '__doc__': None,
#   '__init__': <function Graph.__init__ at 0x00000251DE32DA60>,
#   '__module__': '__main__',
#   '__repr__': <function Graph.__repr__ at 0x00000251DE32DCA0>,
#   '__str__': <function Graph.__str__ at 0x00000251DE32DC10>,
#   '__weakref__': <attribute '__weakref__' of 'Graph' objects>,
#   'all_nodes': <function Graph.all_nodes at 0x00000251DE32DB80>,
#   'set_next': <function Graph.set_next at 0x00000251DE32DAF0>},
#  (<class '__main__.Graph'>, <class 'object'>),
#  <function Graph.__init__ at 0x00000251DE32DA60>,
#  <function Graph.set_next at 0x00000251DE32DAF0>,
#  <function Graph.all_nodes at 0x00000251DE32DB80>,
#  <function Graph.__str__ at 0x00000251DE32DC10>,
#  <function Graph.__repr__ at 0x00000251DE32DCA0>,
#  <function Graph.__del__ at 0x00000251DE32DD30>,
#  <attribute '__dict__' of 'Graph' objects>,
#  <attribute '__weakref__' of 'Graph' objects>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE31EA40>,
#  <frame at 0x00000251DE328A40, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DD887C00>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF0C0>,
#  <frame at 0x00000251DCA0E7C0, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF700>,
#  <frame at 0x00000251DE350040, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE256F40>,
#  <frame at 0x00000251DDD90880, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE334740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2570, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDE9B1D0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 8, 903426, tzinfo=datetime.timezone.utc),
#              'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30E800>,
#  <frame at 0x00000251DDE9C190, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE245240>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE245580>,
#  <frame at 0x00000251DCA0F000, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE245F80>,
#  <frame at 0x00000251DE350440, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2456C0>,
#  <frame at 0x00000251DDBD09D0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBCF490, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD1CF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD901F0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 7, 457825, tzinfo=datetime.timezone.utc),
#              'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <traceback object at 0x00000251DE352AC0>,
#  AttributeError("'tuple' object has no attribute 'set_next'"),
#  <traceback object at 0x00000251DE352B00>,
#  <frame at 0x00000251DC8C8250, file 'D:\\Anaconda\\lib\\site-packages\\IPython\\core\\interactiveshell.py', line 3363, code run_code>,
#  <frame at 0x00000251DC952A00, file '<ipython-input-3-5ce870f7c563>', line 4, code <module>>,
#  <frame at 0x00000251DDD90420, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 9, 691272, tzinfo=datetime.timezone.utc),
#              'msg_id': 'bcfba0d3a446416080b1d86dc96204f8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'bcfba0d3a446416080b1d86dc96204f8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <ExecutionResult object at 251de2fed00, execution_count=3 error_before_exec=None error_in_exec='tuple' object has no attribute 'set_next' info=<ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True> result=None>,
#  {'error_in_exec': AttributeError("'tuple' object has no attribute 'set_next'"),
#   'execution_count': 3,
#   'info': <ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True>},
#  <ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE407500>,
#  <frame at 0x00000251DDD8FB60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2BF2C0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF240>,
#  <frame at 0x00000251DBD2BF40, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF680>,
#  <frame at 0x00000251DE350240, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2BFCC0>,
#  <frame at 0x00000251DDE9B9B0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBD0BF0, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBCFD10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>]
#
#
# After 2 references removed:
# one->two->three
# Collecting...
# Unreachable objects: 0
# Garbage:
# [('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2FF640>,
#  <frame at 0x00000251DE27CA60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE315980>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE3153C0>,
#  <frame at 0x00000251DCA0D740, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE315700>,
#  <frame at 0x00000251DE275C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE315900>,
#  <frame at 0x00000251DE24B780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE279C80, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBBC9B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD8DEF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 3, 490484, tzinfo=datetime.timezone.utc),
#              'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'f5cee1d8f69d43a28580f9bf08a508e8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE310480>,
#  <frame at 0x00000251DDBBC790, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE30B340>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30B540>,
#  <frame at 0x00000251DCA0D110, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE30B640>,
#  <frame at 0x00000251DE348840, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE305580>,
#  <frame at 0x00000251DE347780, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE33B200, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2DF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#  {'_action_max_length': 0,
#   '_current_indent': 0,
#   '_current_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_indent_increment': 2,
#   '_level': 0,
#   '_long_break_matcher': re.compile('\\n\\n\\n+'),
#   '_max_help_position': 24,
#   '_prog': 'named_script_magic',
#   '_root_section': <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#   '_whitespace_matcher': re.compile('\\s+', re.ASCII),
#   '_width': 118},
#  <argparse.HelpFormatter._Section object at 0x00000251DE30DDC0>,
#  {'formatter': <IPython.core.magic_arguments.MagicHelpFormatter object at 0x00000251DE312A60>,
#   'heading': None,
#   'items': [],
#   'parent': None},
#  [],
#  <frame at 0x00000251DDD8E7B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 2, 657550, tzinfo=datetime.timezone.utc),
#              'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'c96133408ffb47c08dc5feef639364ea',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <frame at 0x00000251DDD90F10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 21, 4, 358937, tzinfo=datetime.timezone.utc),
#              'msg_id': 'd417b7a01cf341c5830432383ad20933',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'd417b7a01cf341c5830432383ad20933',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2E3700>,
#  <frame at 0x00000251DE381DC0, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CCBC0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CCE80>,
#  <frame at 0x00000251DCA0DF80, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CC800>,
#  <frame at 0x00000251DE345C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CC900>,
#  <frame at 0x00000251DDBCFAF0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE353740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD18B0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE265A80>,
#  <frame at 0x00000251DE3F2840, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2CAB80>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2CA100>,
#  <frame at 0x00000251DCA0D530, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2CAFC0>,
#  <frame at 0x00000251DE3F2C40, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2CA7C0>,
#  <frame at 0x00000251DE3F6040, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBBB470, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2350, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <class '__main__.WeakGraph'>,
#  {'__doc__': None,
#   '__module__': '__main__',
#   'set_next': <function WeakGraph.set_next at 0x00000251DE32DDC0>},
# ...
#  (<cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,),
#  <cell at 0x00000251DE356B20: type object at 0x00000251DD9A06D0>,
#  <class '__main__.Graph'>,
#  {'__del__': <function Graph.__del__ at 0x00000251DE32DD30>,
#   '__dict__': <attribute '__dict__' of 'Graph' objects>,
#   '__doc__': None,
#   '__init__': <function Graph.__init__ at 0x00000251DE32DA60>,
#   '__module__': '__main__',
#   '__repr__': <function Graph.__repr__ at 0x00000251DE32DCA0>,
#   '__str__': <function Graph.__str__ at 0x00000251DE32DC10>,
#   '__weakref__': <attribute '__weakref__' of 'Graph' objects>,
#   'all_nodes': <function Graph.all_nodes at 0x00000251DE32DB80>,
#   'set_next': <function Graph.set_next at 0x00000251DE32DAF0>},
#  (<class '__main__.Graph'>, <class 'object'>),
#  <function Graph.__init__ at 0x00000251DE32DA60>,
#  <function Graph.set_next at 0x00000251DE32DAF0>,
#  <function Graph.all_nodes at 0x00000251DE32DB80>,
#  <function Graph.__str__ at 0x00000251DE32DC10>,
#  <function Graph.__repr__ at 0x00000251DE32DCA0>,
#  <function Graph.__del__ at 0x00000251DE32DD30>,
#  <attribute '__dict__' of 'Graph' objects>,
#  <attribute '__weakref__' of 'Graph' objects>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE31EA40>,
#  <frame at 0x00000251DE328A40, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DD887C00>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF0C0>,
#  <frame at 0x00000251DCA0E7C0, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF700>,
#  <frame at 0x00000251DE350040, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE256F40>,
#  <frame at 0x00000251DDD90880, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DE334740, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD2570, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDE9B1D0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 8, 903426, tzinfo=datetime.timezone.utc),
#              'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '278a661400f843638f2bbfbf6cd013f9',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'gc.set_debug(gc.DEBUG_LEAK)',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE30E800>,
#  <frame at 0x00000251DDE9C190, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE245240>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE245580>,
#  <frame at 0x00000251DCA0F000, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE245F80>,
#  <frame at 0x00000251DE350440, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2456C0>,
#  <frame at 0x00000251DDBD09D0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBCF490, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBD1CF0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>,
#  <frame at 0x00000251DDD901F0, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': 'import gc\n'
#                       'from pprint import pprint\n'
#                       'import weakref\n'
#                       '\n'
#                       'class Graph:\n'
#                       '    def __init__(self, name):\n'
#                       '        self.name = name\n'
#                       '        self.other = None\n'
#                       '    def set_next(self, other):\n'
#                       '        print(f"{self.name}.set_next({self.other}, '
#                       '{type(other)})")\n'
#                       '        self.other = other\n'
#                       '    def all_nodes(self):\n'
#                       '        "Generate the nodes in the graph sequence."\n'
#                       '        yield self\n'
#                       '        n = self.other\n'
#                       '        while n and n.name != self.name:\n'
#                       '            yield n\n'
#                       '            n = n.other\n'
#                       '        if n is self:\n'
#                       '            yield n\n'
#                       '        return\n'
#                       '    def __str__(self):\n'
#                       '        return "->".join([n.name for n in '
#                       'self.all_nodes()])\n'
#                       '    def __repr__(self):\n'
#                       '        return '
#                       'f"{self.__class__.__name__}({self.name})"\n'
#                       '    def __del__(self):\n'
#                       "        print (f'(Deleting {self.name})')\n"
#                       '        self.set_next(None)\n'
#                       '        \n'
#                       '        \n'
#                       'class WeakGraph(Graph):\n'
#                       '    def set_next(self, other):\n'
#                       '        if other is not None:\n'
#                       '            if self in other.all_nodes():\n'
#                       '                other = weakref.proxy(other)\n'
#                       '        super(WeakGraph, self).set_next(other)\n'
#                       '        return\n'
#                       '    \n'
#                       'def collect_and_show_garbage():\n'
#                       '    "show what garbage is present."\n'
#                       '    print("Collecting...")\n'
#                       '    n = gc.collect()\n'
#                       '    print("Unreachable objects:", n)\n'
#                       '    print("Garbage:")\n'
#                       '    pprint(gc.garbage)\n'
#                       '\n'
#                       'def demo(graph_factory):\n'
#                       '    print("Set up graph:")\n'
#                       '    one = graph_factory("one")\n'
#                       '    two = graph_factory("two")\n'
#                       '    three = graph_factory("three")\n'
#                       '    one.set_next(two)\n'
#                       '    two.set_next(three)\n'
#                       '    three.set_next(one)\n'
#                       '    \n'
#                       '    print("\\nGraphs:")\n'
#                       '    print(str(one))\n'
#                       '    print(str(two))\n'
#                       '    print(str(three))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       "    print('\\n')\n"
#                       '    three = None\n'
#                       '    two = None\n'
#                       '    print("After 2 references removed:")\n'
#                       '    print(str(one))\n'
#                       '    collect_and_show_garbage()     \n'
#                       '    \n'
#                       '    print("\\n")\n'
#                       '    print("Removing last reference:")\n'
#                       '    one = None\n'
#                       '    collect_and_show_garbage()      ',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 7, 457825, tzinfo=datetime.timezone.utc),
#              'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': '3d1817bf5b8b4f2f8c66e85ed6902858',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': 'import gc\n'
#           'from pprint import pprint\n'
#           'import weakref\n'
#           '\n'
#           'class Graph:\n'
#           '    def __init__(self, name):\n'
#           '        self.name = name\n'
#           '        self.other = None\n'
#           '    def set_next(self, other):\n'
#           '        print(f"{self.name}.set_next({self.other}, '
#           '{type(other)})")\n'
#           '        self.other = other\n'
#           '    def all_nodes(self):\n'
#           '        "Generate the nodes in the graph sequence."\n'
#           '        yield self\n'
#           '        n = self.other\n'
#           '        while n and n.name != self.name:\n'
#           '            yield n\n'
#           '            n = n.other\n'
#           '        if n is self:\n'
#           '            yield n\n'
#           '        return\n'
#           '    def __str__(self):\n'
#           '        return "->".join([n.name for n in self.all_nodes()])\n'
#           '    def __repr__(self):\n'
#           '        return f"{self.__class__.__name__}({self.name})"\n'
#           '    def __del__(self):\n'
#           "        print (f'(Deleting {self.name})')\n"
#           '        self.set_next(None)\n'
#           '        \n'
#           '        \n'
#           'class WeakGraph(Graph):\n'
#           '    def set_next(self, other):\n'
#           '        if other is not None:\n'
#           '            if self in other.all_nodes():\n'
#           '                other = weakref.proxy(other)\n'
#           '        super(WeakGraph, self).set_next(other)\n'
#           '        return\n'
#           '    \n'
#           'def collect_and_show_garbage():\n'
#           '    "show what garbage is present."\n'
#           '    print("Collecting...")\n'
#           '    n = gc.collect()\n'
#           '    print("Unreachable objects:", n)\n'
#           '    print("Garbage:")\n'
#           '    pprint(gc.garbage)\n'
#           '\n'
#           'def demo(graph_factory):\n'
#           '    print("Set up graph:")\n'
#           '    one = graph_factory("one")\n'
#           '    two = graph_factory("two")\n'
#           '    three = graph_factory("three")\n'
#           '    one.set_next(two)\n'
#           '    two.set_next(three)\n'
#           '    three.set_next(one)\n'
#           '    \n'
#           '    print("\\nGraphs:")\n'
#           '    print(str(one))\n'
#           '    print(str(two))\n'
#           '    print(str(three))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           "    print('\\n')\n"
#           '    three = None\n'
#           '    two = None\n'
#           '    print("After 2 references removed:")\n'
#           '    print(str(one))\n'
#           '    collect_and_show_garbage()     \n'
#           '    \n'
#           '    print("\\n")\n'
#           '    print("Removing last reference:")\n'
#           '    one = None\n'
#           '    collect_and_show_garbage()      ',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <traceback object at 0x00000251DE352AC0>,
#  AttributeError("'tuple' object has no attribute 'set_next'"),
#  <traceback object at 0x00000251DE352B00>,
#  <frame at 0x00000251DC8C8250, file 'D:\\Anaconda\\lib\\site-packages\\IPython\\core\\interactiveshell.py', line 3363, code run_code>,
#  <frame at 0x00000251DC952A00, file '<ipython-input-3-5ce870f7c563>', line 4, code <module>>,
#  <frame at 0x00000251DDD90420, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 282, code dispatch_shell>,
#  [b'59a877b36e7a49ecaf785dfc409ef2c5'],
#  {'buffers': [],
#   'content': {'allow_stdin': True,
#               'code': "print ('Setting up the cycle\\n')\n"
#                       'demo(Graph)\n'
#                       "print('\\nBreaking the cycle and cleaning up "
#                       "garbage\\n')\n"
#                       'gc.garbage[0].set_next(None)\n'
#                       'while gc.garbage:\n'
#                       '    del gc.garbage[0]\n'
#                       "print('\\n')\n"
#                       'collect_and_show_garbage()',
#               'silent': False,
#               'stop_on_error': True,
#               'store_history': True,
#               'user_expressions': {}},
#   'header': {'date': datetime.datetime(2021, 2, 17, 1, 22, 9, 691272, tzinfo=datetime.timezone.utc),
#              'msg_id': 'bcfba0d3a446416080b1d86dc96204f8',
#              'msg_type': 'execute_request',
#              'session': '59a877b36e7a49ecaf785dfc409ef2c5',
#              'username': 'username',
#              'version': '5.2'},
#   'metadata': {},
#   'msg_id': 'bcfba0d3a446416080b1d86dc96204f8',
#   'msg_type': 'execute_request',
#   'parent_header': {}},
#  {'allow_stdin': True,
#   'code': "print ('Setting up the cycle\\n')\n"
#           'demo(Graph)\n'
#           "print('\\nBreaking the cycle and cleaning up garbage\\n')\n"
#           'gc.garbage[0].set_next(None)\n'
#           'while gc.garbage:\n'
#           '    del gc.garbage[0]\n'
#           "print('\\n')\n"
#           'collect_and_show_garbage()',
#   'silent': False,
#   'stop_on_error': True,
#   'store_history': True,
#   'user_expressions': {}},
#  [],
#  <ExecutionResult object at 251de2fed00, execution_count=3 error_before_exec=None error_in_exec='tuple' object has no attribute 'set_next' info=<ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True> result=None>,
#  {'error_in_exec': AttributeError("'tuple' object has no attribute 'set_next'"),
#   'execution_count': 3,
#   'info': <ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True>},
#  <ExecutionInfo object at 251de2fec70, raw_cell="print ('Setting up the cycle\n')
# demo(Graph)
# print.." store_history=True silent=False shell_futures=True>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE407500>,
#  <frame at 0x00000251DDD8FB60, file 'D:\\Anaconda\\lib\\enum.py', line 608, code _missing_>,
#  <traceback object at 0x00000251DE2BF2C0>,
#  ('<built-in function default_int_handler> is not a valid Handlers',),
#  ValueError('<built-in function default_int_handler> is not a valid Handlers'),
#  <traceback object at 0x00000251DE2BF240>,
#  <frame at 0x00000251DBD2BF40, file 'D:\\Anaconda\\lib\\enum.py', line 595, code __new__>,
#  <traceback object at 0x00000251DE2BF680>,
#  <frame at 0x00000251DE350240, file 'D:\\Anaconda\\lib\\enum.py', line 304, code __call__>,
#  <traceback object at 0x00000251DE2BFCC0>,
#  <frame at 0x00000251DDE9B9B0, file 'D:\\Anaconda\\lib\\signal.py', line 32, code _int_to_enum>,
#  <frame at 0x00000251DDBD0BF0, file 'D:\\Anaconda\\lib\\signal.py', line 48, code signal>,
#  <frame at 0x00000251DDBCFD10, file 'D:\\Anaconda\\lib\\site-packages\\ipykernel\\kernelbase.py', line 291, code post_handler_hook>]
